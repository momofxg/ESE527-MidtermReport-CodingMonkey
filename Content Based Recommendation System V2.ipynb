# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cleaned_score.csv')
df = df.drop(columns=['Unnamed: 0']) # drop useless column

# %%
#df_score = df.copy()
#df_score = df_score.dropna(subset=['score'])
#df_score = df_score.loc[df_score['score'] >=5.5 ]

# %%
# Turn all characters into lower case and delete all spaces
def lower_space(x):
        return str.lower(x.replace(" ", ""))
    
def lower_only(x):
        return str.lower(x)

# %%
# Select useful features to be processed by lower_space()
features=['type','title','director','cast','country','release_year','rating','listed_in','score']
df_lower = df.copy()
df_lower=df_lower[features]

# create dictionary of ordinal to integer mapping
ord = {'TV-Y':'ratt', 'TV-Y7':'ratt', 'TV-Y7-FV':'ratt', 
            'G':'ratt ratt', 'TV-G':'ratt ratt', 'PG':'ratt ratt','TV-PG':'ratt ratt', 
            'PG-13':'ratt ratt ratt', 'TV-14':'ratt ratt ratt', 
            'R':'rattt', 'NC-17':'rattt', 'TV-MA':'rattt',
            'NR':'norated', 'UR':'norated', 'No Rated':'norated'}
# apply using map

df_lower['rating'] = df_lower['rating'].map(ord)

df_lower['title'] = df_lower['title'].apply(lower_only)
for feature in features:
    if feature != 'release_year' and feature != 'score'and feature != 'title' and feature != 'rating':
        df_lower[feature] = df_lower[feature].apply(lower_space)
    
df_lower['cast'] = df_lower['cast'].apply(lambda x: x.strip().split(',')[:3])
df_lower['cast'] = [','.join(map(str, l)) for l in df_lower['cast']]
df_lower.head(2)
# Out:
#      type                 title        director  \
# 0   movie  dick johnson is dead  kirstenjohnson
# 1  tvshow         blood & water          nodata
#
#                                 cast       country  release_year  \
# 0                             nodata  unitedstates          2020
# 1  amaqamata,khosingema,gailmabalane   southafrica          2021
#
#            rating                                  listed_in  score
# 0  ratt ratt ratt                              documentaries    7.4
# 1           rattt  internationaltvshows,tvdramas,tvmysteries    6.6

# %%
# function for creating bag-of-words
def create_soup(x):
    #return x['type']+ ' ' + x['title']+ ' ' + x['director'] + ' ' + x['cast'] + ' ' + x['country'] + ' ' + x['release_year'] + ' ' + x['rating'] + ' ' +x['listed_in']+' '+ x['description']+' '+ x['score']
    return x['type']+ ' ' + x['title']+ ' ' + x['director'] + ' ' + x['cast'] + ' ' + x['country'] + ' ' + x['release_year'] + ' ' + x['rating'] + ' ' +x['listed_in']

# %%
# create bag-of-words
df_str = df_lower.copy()
df_str = df_str.applymap(str)
df_str['soup'] = df_str.apply(create_soup, axis=1)
df_str['soup']
# Out:
# 0       movie dick johnson is dead kirstenjohnson noda...
# 1       tvshow blood & water nodata amaqamata,khosinge...
# 2       tvshow ganglands julienleclercq samibouajila,t...
# 3       tvshow jailbirds new orleans nodata nodata nod...
# 4       tvshow kota factory nodata mayurmore,jitendrak...
#                               ...
# 8789    movie zodiac davidfincher markruffalo,jakegyll...
# 8790    tvshow zombie dumb nodata nodata nodata 2018 r...
# 8791    movie zombieland rubenfleischer jesseeisenberg...
# 8792    movie zoom peterhewitt timallen,courteneycox,c...
# 8793    movie zubaan mozezsingh vickykaushal,sarah-jan...
# Name: soup, Length: 8794, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# generate Count Vectorizer matrix
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df_str['soup'])

# generate Cosine Similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# use movie titiles as indices
df_str=df_str.reset_index()
indices = pd.Series(df_str.index, index=df_str['title'])
indices
# Out:
# title
# dick johnson is dead        0
# blood & water               1
# ganglands                   2
# jailbirds new orleans       3
# kota factory                4
#                          ...
# zodiac                   8789
# zombie dumb              8790
# zombieland               8791
# zoom                     8792
# zubaan                   8793
# Length: 8794, dtype: int64

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    title=title.lower()
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with the input movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    top_recom = []
    for i in sim_scores:
        if df['score'].iloc[i[0]]>= 7.0 and df['director'].iloc[i[0]]!="No Data" and df['cast'].iloc[i[0]]!="No Data" and df['country'].iloc[i[0]]!="No Data":
            top_recom.append(i[0])
    # Get the indices of the 10 most similar movies
    top_recom = top_recom[1:11]

    # Return the top 10 most similar movies
    features=['type','title','director','cast','country','release_year','rating','listed_in','description','score']
    return df[features].iloc[top_recom]

# %%
get_recommendations('Women Behind Bars', cosine_sim)
# Out:
#          type                             title         director  \
# 676   TV Show                         Riverdale  Rob Seidenglanz
# 2947  TV Show                             Arrow    James Bamford
# 6657    Movie                            Easy A       Will Gluck
# 7842    Movie                       Remember Me    Allen Coulter
# 8498    Movie                The Social Network    David Fincher
# 380   TV Show                         The Flash      Glen Winter
# 1387    Movie               The Next Three Days      Paul Haggis
# 5096  TV Show  Fullmetal Alchemist: Brotherhood    Yasuhiro Irie
# 797     Movie                          I Am Sam    Jessie Nelson
# 3278    Movie                         SunGanges    Valli Bindana
#
#                                                    cast  \
# 676   K.J. Apa, Lili Reinhart, Camila Mendes, Cole S...
# 2947  Stephen Amell, Katie Cassidy, David Ramsey, Wi...
# 6657  Emma Stone, Penn Badgley, Amanda Bynes, Dan By...
# 7842  Robert Pattinson, Emilie de Ravin, Chris Coope...
# 8498  Jesse Eisenberg, Andrew Garfield, Justin Timbe...
# 380   Grant Gustin, Candice Patton, Danielle Panabak...
# 1387  Russell Crowe, Elizabeth Banks, Brian Dennehy,...
# 5096  Romi Park, Rie Kugimiya, Megumi Takamoto, Shin...
# 797   Sean Penn, Michelle Pfeiffer, Dakota Fanning, ...
# 3278                                   Naseeruddin Shah
#
#                     country  release_year rating  \
# 676           United States          2019  TV-14
# 2947          United States          2019  TV-14
# 6657          United States          2010  PG-13
# 7842          United States          2010  PG-13
# 8498          United States          2010  PG-13
# 380           United States          2021  TV-14
# 1387  United States, France          2010  PG-13
# 5096                  Japan          2010  TV-14
# 797           United States          2001  PG-13
# 3278   India, United States          2018  TV-14
#
#                                               listed_in  \
# 676             Crime TV Shows, TV Dramas, TV Mysteries
# 2947              Crime TV Shows, TV Action & Adventure
# 6657                          Comedies, Romantic Movies
# 7842                            Dramas, Romantic Movies
# 8498                                             Dramas
# 380   Crime TV Shows, TV Action & Adventure, TV Sci-...
# 1387                                  Dramas, Thrillers
# 5096               Anime Series, International TV Shows
# 797                                              Dramas
# 3278                Documentaries, International Movies
#
#                                             description  score
# 676   While navigating the troubled waters of sex, r...    7.5
# 2947  Based on DC Comics' Green Arrow, an affluent p...    7.5
# 6657  When a lie about Olive's reputation transforms...    7.1
# 7842  Tyler's still feeling lost following the trage...    7.1
# 8498  Director David Fincher's biographical drama ch...    7.7
# 380   A forensics expert who wakes from a coma with ...    7.6
# 1387  When his wife becomes a murder suspect and is ...    7.3
# 5096  After both suffer physical damage – brothers E...    9.1
# 797   When the legal system declares him unfit to be...    7.6
# 3278  A trio of filmmakers treks across India to exp...    7.8

# %%
get_recommendations('Thor: Ragnarok', cosine_sim)
# Out:
#        type                 title           director  \
# 7431  Movie          Men in Black   Barry Sonnenfeld
# 6167  Movie  Ant-Man and the Wasp        Peyton Reed
# 946   Movie              Stargate    Roland Emmerich
# 5955  Movie                     9        Shane Acker
# 6498  Movie           Cloverfield        Matt Reeves
# 594   Movie             Star Trek        J.J. Abrams
# 6320  Movie         Black Panther       Ryan Coogler
# 8518  Movie      The Time Machine        Simon Wells
# 340   Movie             Inception  Christopher Nolan
# 1957  Movie            Real Steel         Shawn Levy
#
#                                                    cast  \
# 7431  Tommy Lee Jones, Will Smith, Linda Fiorentino,...
# 6167  Paul Rudd, Evangeline Lilly, Michael Douglas, ...
# 946   Kurt Russell, James Spader, Jaye Davidson, Viv...
# 5955  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 6498  Lizzy Caplan, Jessica Lucas, T.J. Miller, Mich...
# 594   Chris Pine, Zachary Quinto, Karl Urban, Zoe Sa...
# 6320  Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 8518  Guy Pearce, Samantha Mumba, Jeremy Irons, Mark...
# 340   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1957  Hugh Jackman, Dakota Goyo, Evangeline Lilly, A...
#
#                                   country  release_year rating  \
# 7431                        United States          1997  PG-13
# 6167                        United States          2018  PG-13
# 946                 United States, France          1994  PG-13
# 5955                        United States          2009  PG-13
# 6498                        United States          2008  PG-13
# 594                United States, Germany          2009  PG-13
# 6320                        United States          2018  PG-13
# 8518  United States, United Arab Emirates          2002  PG-13
# 340         United States, United Kingdom          2010  PG-13
# 1957                 United States, India          2011  PG-13
#
#                                               listed_in  \
# 7431     Action & Adventure, Comedies, Sci-Fi & Fantasy
# 6167     Action & Adventure, Comedies, Sci-Fi & Fantasy
# 946                Action & Adventure, Sci-Fi & Fantasy
# 5955  Action & Adventure, Independent Movies, Sci-Fi...
# 6498  Action & Adventure, Horror Movies, Sci-Fi & Fa...
# 594                Action & Adventure, Sci-Fi & Fantasy
# 6320               Action & Adventure, Sci-Fi & Fantasy
# 8518               Action & Adventure, Sci-Fi & Fantasy
# 340     Action & Adventure, Sci-Fi & Fantasy, Thrillers
# 1957  Action & Adventure, Sci-Fi & Fantasy, Sports M...
#
#                                             description  score
# 7431  A streetwise cop teams with a veteran governme...    7.3
# 6167  Problems big and small pop up when Scott Lang,...    7.1
# 946   An Egyptologist joins a mission into the unkno...    7.1
# 5955  In a postapocalyptic world, rag-doll robots hi...    7.7
# 6498  A going-away party in Manhattan is interrupted...    7.0
# 594   On their first voyage aboard the starship Ente...    7.9
# 6320  T'Challa, the superpowered new leader of the h...    7.3
# 8518  Based on the H.G. Wells classic, this adventur...    7.6
# 340   A troubled thief who extracts secrets from peo...    8.8
# 1957  A struggling fighter-turned-promoter reconnect...    7.1

# %%
get_recommendations('Sankofa', cosine_sim)
# Out:
#        type               title                    director  \
# 6511  Movie             Colonia        Florian Gallenberger
# 3125  Movie     The Danish Girl                  Tom Hooper
# 2895  Movie      System Crasher            Nora Fingscheidt
# 7317  Movie               Locke               Steven Knight
# 2467  Movie  I'm No Longer Here  Fernando Frías de la Parra
# 4626  Movie         In Darkness               Anthony Byrne
# 6140  Movie      American Honey               Andrea Arnold
# 6711  Movie          Ex Machina                Alex Garland
# 8072  Movie          Starred Up             David Mackenzie
# 8565  Movie              Thithi                  Raam Reddy
#
#                                                    cast  \
# 6511  Emma Watson, Daniel Brühl, Michael Nyqvist, Ri...
# 3125  Eddie Redmayne, Alicia Vikander, Ben Whishaw, ...
# 2895  Helena Zengel, Albrecht Schuch, Gabriela Maria...
# 7317  Tom Hardy, Olivia Colman, Ruth Wilson, Andrew ...
# 2467  Juan Daniel García, Angelina Chen, Jonathan Es...
# 4626  Natalie Dormer, Ed Skrein, Emily Ratajkowski, ...
# 6140  Sasha Lane, Shia LaBeouf, Riley Keough, McCaul...
# 6711  Domhnall Gleeson, Alicia Vikander, Oscar Isaac...
# 8072  Jack O'Connell, Ben Mendelsohn, Rupert Friend,...
# 8565  Thammegowda S., Channegowda, Abhishek H.N., Po...
#
#                                                 country  release_year rating  \
# 6511  Germany, France, Luxembourg, United Kingdom, U...          2015      R
# 3125  United Kingdom, United States, Germany, Denmar...          2015      R
# 2895                                            Germany          2020  TV-MA
# 7317                      United Kingdom, United States          2013      R
# 2467                              Mexico, United States          2019  TV-MA
# 4626                      United Kingdom, United States          2018  TV-MA
# 6140                      United Kingdom, United States          2016      R
# 6711                                     United Kingdom          2015      R
# 8072                                     United Kingdom          2013  TV-MA
# 8565                               India, United States          2015  TV-MA
#
#                                               listed_in  \
# 6511   Dramas, Independent Movies, International Movies
# 3125   Dramas, Independent Movies, International Movies
# 2895   Dramas, Independent Movies, International Movies
# 7317                         Dramas, Independent Movies
# 2467   Dramas, Independent Movies, International Movies
# 4626  Independent Movies, International Movies, Thri...
# 6140                         Dramas, Independent Movies
# 6711   Dramas, Independent Movies, International Movies
# 8072   Dramas, Independent Movies, International Movies
# 8565   Dramas, Independent Movies, International Movies
#
#                                             description  score
# 6511  When her boyfriend is caught up in a Chilean c...    7.1
# 3125  In 1920s Denmark, married artists embark on a ...    7.1
# 2895  Traumatized, violent and yearning for love, 9-...    7.8
# 7317  Over the space of 90 minutes, Ivan Locke's lif...    7.1
# 2467  A terrible misunderstanding with a local gang ...    7.3
# 4626  A blind pianist fears for her life after the s...    7.3
# 6140  A teenage girl leaves her dull life in Oklahom...    7.0
# 6711  A coder at a tech company wins a week-long ret...    7.7
# 8072  A British juvenile offender's violent temper g...    7.4
# 8565  In a South Indian village, a centenarian's fun...    8.0
